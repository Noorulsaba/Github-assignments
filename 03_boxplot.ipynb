# %%
#import library
import seaborn as sns
#canvas (balloon board)
sns.set_style("whitegrid")
# load dataset
Ship = sns.load_dataset("titanic")
Ship
# draw a box plot
sns.boxplot(x="class", y="fare", data=Ship)
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
import seaborn as sns
sns.set_style("whitegrid")
tip = sns.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
sns.set_style("whitegrid")
tip = sns.load_dataset("tips")
tip
sns.boxplot(x="day", y="tip", data=tip)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
sns.set_style("whitegrid")
tip = sns.load_dataset("tips")
tip
sns.boxplot(x="day", y="tip", data=tip, saturation= 5.5)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

tip = sns.load_dataset("tips")
tip.describe
# Out:
# <bound method NDFrame.describe of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn as sns
sns.set_style("whitegrid")
tip = sns.load_dataset("tips")
tip
sns.boxplot(x=tip["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
import seaborn as sns
sns.set_style("whitegrid")
tip = sns.load_dataset("tips")
tip
sns.boxplot(y=tip["total_bill"])
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %%
import seaborn as sns
sns.set_style("whitegrid")
tip = sns.load_dataset("tips")
tip
sns.boxplot(y=tip["size"])
# Out:
# <AxesSubplot:ylabel='size'>

# %%
import seaborn as sns
sns.set_style("whitegrid")
tip = sns.load_dataset("tips")
tip
sns.boxplot(x="tip", y="day", hue="smoker",data=tip, palette="Set2", dodge=True)
#To manage individual color for each hue color:
#sns.boxplot(x="tip", y="day", saturation= 1, data=tip, orient="h", hue="smoker",palette ={"Yes": "0.4", "No":"0.8"})
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
sns.set_style("whitegrid")
tip = sns.load_dataset("tips")
tip
sns.boxplot(x="tip", y="day", hue="smoker",data=tip, palette="Set2", dodge=False)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
sns.set_style("whitegrid")
tip = sns.load_dataset("tips")
tip
sns.boxplot(x="tip", y="day", hue="smoker",data=tip, palette={"Yes": "0.5", "No":"0.9"}, dodge=False, orient="h")
#orient="v":Vertical orientation requires numeric `y` variable. that's why we cannot make it vertical and similarly for x asix
#In order to make orient feature applicable, 'y' should always be numeric. We're using categorical values that's why giving error.
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
sns.set_style("whitegrid")
tip = sns.load_dataset("tips")
tip
sns.boxplot(x="tip", y="day", data=tip, color="#faee05")
#we can choose color via hex color picker
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
ship=sns.load_dataset("titanic")
ship.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import seaborn as sns
import pandas as pd
import numpy as np
ship=sns.load_dataset("titanic")
ship.head()
sns.boxplot(x="fare", y="sex", data=ship)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='sex'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
ship=sns.load_dataset("titanic")
ship.head()
sns.boxplot(x="embark_town", y="fare", data=ship)
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='fare'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
ship=sns.load_dataset("titanic")
ship.head()
sns.boxplot(x="survived", y="age", data=ship, saturation= 7.5, color="#45fc03")
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %% [markdown]
# ## Interquartile range
# - The IQR describes the middle 50% of values when ordered from lowest to highest. To find the interquartile range (IQR):
# - first find the median (middle value) of the lower and upper half of the data.
# - These values are quartile 1 (Q1) and quartile 3 (Q3).
# - The IQR is the difference between Q3 and Q1.

# %% [markdown]
# ## Outlier
# - Outlier is a data point that differs significantly from other observations.
# - An outlier may be due to variability in the measurement or it may indicate experimental error; the   latter are sometimes excluded from the data set.
# - An outlier can cause serious problems in statistical analyses
# - maximum non-outlier data, minimum non_outlier data

# %%
sns.boxplot(x="survived", y="age", showmeans=True, 
            meanprops={"marker":"*", "markersize":"20", "markeredgecolor":"#470470"},
            data=ship)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.boxplot(x="survived", y="age", showmeans=True, 
            meanprops={"marker":"+", "markersize":"18", "markeredgecolor":"white"},
            data=ship)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
import matplotlib.pyplot as plt
sns.boxplot(x="survived", y="age", showmeans=True, 
            meanprops={"marker":"+", "markersize":"18", "markeredgecolor":"white"},
            data=ship)
plt.xlabel("Survived", size=12),
plt.ylabel("Age(years)",size=14),
plt.title("Thakur kitny aadmi thy",size=16, weight="bold")
# Out:
# Text(0.5, 1.0, 'Thakur kitny aadmi thy')

# %% [markdown]
# # Facet wrap
# - facet_wrap() makes a long ribbon of panels (generated by any number of variables) and wraps it into   2d. This is useful if you have a single variable with many levels and want to arrange the plots in   a more space efficient manner.
# - You can control how the ribbon is wrapped into a grid with ncol, nrow, as.table and dir.
# - ncol and nrow control how many columns and rows (you only need to set one).
# - as.table controls whether the facets are laid out like a table (TRUE), with highest values at the     bottom-right, or a plot (FALSE), with the highest values at the top-right.
# - dir controls the direction of wrap: horizontal or vertical.
#
# # Facet grid
# - Facet_grid() forms a matrix of panels defined by row and column faceting variables. It is most       useful when you have two discrete variables, and all combinations of the variables exist in the       data.
# - You can use multiple variables in the rows or columns, by "adding" them together, e.g. a + b ~ c +   d.
# - facet grid() has an additional parameter called space, which takes the same values as scales.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv(r'C:\Users\nooru\OneDrive\Desktop\chilla.csv')
print (df)
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = chilla= pd.read_csv(r'C:\Users\nooru\OneDrive\Desktop\chilla.csv')
#to Select Subset of Columns:
df = pd.DataFrame(data, columns= ['Gender','Age'])
print (df)
# Out:
#      Gender    Age
# 0      Male  36-40
# 1      Male  26-30
# 2      Male  31-35
# 3    Female  31-35
# 4    Female  26-30
# ..      ...    ...
# 370    Male  26-30
# 371    Male  31-35
# 372    Male  21-25
# 373    Male  26-30
# 374  Female  31-35
#
# [375 rows x 2 columns]

# %%
data = pd.read_csv(r'C:\Users\nooru\OneDrive\Desktop\chilla.csv')
sns.boxplot(x="Gender", y="Height in cm? Freelancer- (Float)", data=chilla)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Height in cm? Freelancer- (Float)'>

# %%
sns.lineplot(x="Your Weight in kg? (float)", y="Age (years)-Float/Int", data=chilla)
plt.title("Body mass index")
sns.set_style("white")

# %%
sns.barplot(x="Qualification_completed", y="Age (years)-Float/Int", data=chilla) 
plt.title("Prha likha Pakistan", size=12, weight="bold")
# Out:
# Text(0.5, 1.0, 'Prha likha Pakistan')

# %%
sns.barplot(x="Your favorite programming language?", 
            y="How many hours you code a day? (int) e.g: 5,4,3",
            data=chilla)
plt.title("Dedicated python chillers", size=16)
# Out:
# Text(0.5, 1.0, 'Dedicated python chillers')

# %%
sns.boxplot(x="Your favorite programming language?", 
            y="How many hours you code a day? (int) e.g: 5,4,3",
            data=chilla, showmeans=True, 
            meanprops={"marker":"*", "markersize":"8"})
plt.title("Dedicated python chillers", size=16)
# Out:
# Text(0.5, 1.0, 'Dedicated python chillers')

# %%
import seaborn as sns
sns.set_theme(style="ticks")

dots = sns.load_dataset("dots")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(
    data=chilla, 
    x="How many hours you code a day? (int) e.g: 5,4,3", y="Age", 
    palette=palette, kind="line",
    height=5, aspect=2.75, facet_kws=dict(sharex=False),
)

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

data = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=chilla, kind="bar",
    x="Age", y="Your Weight in kg? (float)", hue="Gender",
    ci="sd", palette="dark", alpha=.6, height=6
)
plt.title("BMI", size=20, weight="bold")
g.despine(left=True)
g.set_axis_labels("Age")
g.legend.set_title("")
